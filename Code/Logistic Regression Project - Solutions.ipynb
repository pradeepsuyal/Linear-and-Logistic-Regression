# %% [markdown]
# **importing essential libraries**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

import missingno as msno

# %% [markdown]
# **Getting the data**

# %%
ad_data = pd.read_csv('advertising.csv')

# %% [markdown]
# **Checking the head of ad_data**

# %%
ad_data.head()
# Out:
#    Daily Time Spent on Site  Age  Area Income  Daily Internet Usage  \
# 0                     68.95   35     61833.90                256.09
# 1                     80.23   31     68441.85                193.77
# 2                     69.47   26     59785.94                236.50
# 3                     74.15   29     54806.18                245.89
# 4                     68.37   35     73889.99                225.58
#
#                            Ad Topic Line            City  Male     Country  \
# 0     Cloned 5thgeneration orchestration     Wrightburgh     0     Tunisia
# 1     Monitored national standardization       West Jodi     1       Nauru
# 2       Organic bottom-line service-desk        Davidton     0  San Marino
# 3  Triple-buffered reciprocal time-frame  West Terrifurt     1       Italy
# 4          Robust logistical utilization    South Manuel     0     Iceland
#
#              Timestamp  Clicked on Ad
# 0  2016-03-27 00:53:11              0
# ...

# %% [markdown]
# **This dataset has total 10 columns and 1000 rows in which there are 3 float value, 3 integer value, and 4 object value**

# %%
ad_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 10 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Daily Time Spent on Site  1000 non-null   float64
#  1   Age                       1000 non-null   int64
#  2   Area Income               1000 non-null   float64
#  3   Daily Internet Usage      1000 non-null   float64
#  4   Ad Topic Line             1000 non-null   object
#  5   City                      1000 non-null   object
#  6   Male                      1000 non-null   int64
#  7   Country                   1000 non-null   object
#  8   Timestamp                 1000 non-null   object
#  9   Clicked on Ad             1000 non-null   int64
# dtypes: float64(3), int64(3), object(4)
# memory usage: 78.2+ KB

# %%
ad_data.describe()
# Out:
#        Daily Time Spent on Site          Age   Area Income  \
# count               1000.000000  1000.000000   1000.000000
# mean                  65.000200    36.009000  55000.000080
# std                   15.853615     8.785562  13414.634022
# min                   32.600000    19.000000  13996.500000
# 25%                   51.360000    29.000000  47031.802500
# 50%                   68.215000    35.000000  57012.300000
# 75%                   78.547500    42.000000  65470.635000
# max                   91.430000    61.000000  79484.800000
#
#        Daily Internet Usage         Male  Clicked on Ad
# count           1000.000000  1000.000000     1000.00000
# mean             180.000100     0.481000        0.50000
# std               43.902339     0.499889        0.50025
# min              104.780000     0.000000        0.00000
# 25%              138.830000     0.000000        0.00000
# 50%              183.130000     0.000000        0.50000
# ...

# %% [markdown]
# ## Exploratory Data Analysis

# %% [markdown]
# **checking for null value**

# %%
msno.matrix(ad_data)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ***from above and below plot we can see that there are no null values in the dataset***

# %%
msno.bar(ad_data, figsize=(8,6))
# Out:
# <AxesSubplot:>

# %%
sns.set_style('whitegrid')
ad_data['Age'].hist(bins=30)
plt.xlabel('Age')
# Out:
# Text(0.5, 0, 'Age')

# %% [markdown]
# most of the people are in the age  of 29 and 38

# %% [markdown]
# **Creating a jointplot showing Area Income versus Age.**

# %%
sns.jointplot(x='Age',y='Area Income',data=ad_data)

# %% [markdown]
# from above we can see that as the age increased the Avg. Income of geographical area of consumer also increases

# %% [markdown]
# **Creating a jointplot showing the kde distributions of Daily Time spent on site vs. Age.**

# %%
sns.set_style('whitegrid')

# %%
sns.jointplot(x='Age',y='Daily Time Spent on Site',data=ad_data,palette='viridis',kind='kde', color='red')

# %% [markdown]
# people below the age of 35 spent more time on site, which is quite often

# %% [markdown]
# **Creating a jointplot of 'Daily Time Spent on Site' vs. 'Daily Internet Usage'**

# %%
sns.jointplot(x='Daily Time Spent on Site',y='Daily Internet Usage',data=ad_data,color='green')

# %% [markdown]
# as the daily time spent on site increased the internet usage also increases

# %% [markdown]
# **creating a pairplot with the hue defined by the 'Clicked on Ad' column feature.**

# %%
sns.pairplot(ad_data,hue='Clicked on Ad',palette='rainbow')

# %%
sns.boxplot(ad_data['Area Income'])
# Out:
# C:\Users\sudee\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Area Income'>

# %% [markdown]
# from above we can see that average area of income is 55000 and also there are some outlier present in this feature

# %%
sns.scatterplot(x= 'Age', y = 'Daily Internet Usage', data=ad_data,  hue='Male')
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Daily Internet Usage'>

# %%
plt.figure(figsize=(15,10))
sns.heatmap(ad_data.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# most correlated feature are 'Daily internet usage' and 'Daily time spent on site' and least correlated are 'Daily internet usage' and 'clicked on ad'

# %% [markdown]
# ***in this dataset I will be using Logistic regression***

# %% [markdown]
# # Logistic Regression
#
# Now it's time to do a train test split, and train our model!

# %% [markdown]
# ** Splitting the data into training set and testing set using train_test_split**

# %%
from sklearn.model_selection import train_test_split

# %%
X = ad_data[['Daily Time Spent on Site', 'Age', 'Area Income','Daily Internet Usage', 'Male']]
y = ad_data['Clicked on Ad']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %% [markdown]
# ** Training and fitting a logistic regression model on the training set.**

# %%
from sklearn.linear_model import LogisticRegression

# %%
logmodel = LogisticRegression()
logmodel.fit(X_train,y_train)
# Out:
# LogisticRegression()

# %% [markdown]
# ## Predictions and Evaluations
# ** predicting values for the testing data.**

# %%
predictions = logmodel.predict(X_test)

# %% [markdown]
# ** Creating a classification report for the model.**

# %%
from sklearn.metrics import classification_report

# %%
print(classification_report(y_test,predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.86      0.96      0.91       162
#            1       0.96      0.85      0.90       168
#
#     accuracy                           0.91       330
#    macro avg       0.91      0.91      0.91       330
# weighted avg       0.91      0.91      0.91       330

# %%
from sklearn.metrics import accuracy_score

# %%
print(accuracy_score(y_test,predictions))
# Out:
# 0.906060606060606

# %% [markdown]
# **our model shows an accuracy of 90% which is pretty good**
